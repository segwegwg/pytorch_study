# %% [markdown]
# ## 报错1：模型与数据没有都存放于统一device上

# %% [markdown]
# ```python
# RuntimeError                              Traceback (most recent call last)
# Cell In[37], line 4
#       1 #训练函数
#       2 for epoch in range(epochs):
#       3     for batch_x,batch_y in tqdm(train_loader):
# ----> 4         y_pred=model(batch_x)
#       5         loss=criterion(y_pred,batch_y)
#       6
#       7         optimizer.zero_grad()
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# Cell In[35], line 32, in Lenet.forward(self, x)
#      31     def forward(self,x):
# ---> 32         x=self.conv(x)
#      33         x=torch.flatten(x)
#      34         x=self.fc(x)
#      35         return x
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\conv.py:565, in Conv2d.forward(self, input)
#     564 def forward(self, input: Tensor) -> Tensor:
# --> 565     return self._conv_forward(input, self.weight, self.bias)
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\conv.py:560, in Conv2d._conv_forward(self, input, weight, bias)
#     547 if self.padding_mode != "zeros":
#     548     return F.conv2d(
#     549         F.pad(
#     550             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    557         self.groups,
#     558     )
# --> 560 return F.conv2d(
#     561     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     562 )
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same or input should be a MKLDNN tensor and weight is a dense tensor
# ```

# %% [markdown]
# ## 修正
# ```python
# device="cuda:0" if  torch.cuda.is_available() else "cpu"
# model.to(device)
# batch_x=batch_x.to(device)
# batch_y=batch_y.to(device)
# ```

# %% [markdown]
# # 报错2：维度不匹配

# %% [markdown]
# ```python
# RuntimeError                              Traceback (most recent call last)
# Cell In[44], line 7
#       3     for batch_x,batch_y in tqdm(train_loader):
#       4         #一定要保证模型与数据都迁移了
#       5         batch_x = batch_x.to(device)
#       6         batch_y = batch_y.to(device)
# ----> 7         y_pred=model(batch_x)
#       8         loss=criterion(y_pred,batch_y)
#       9
#      10         optimizer.zero_grad()
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# Cell In[41], line 34, in Lenet.forward(self, x)
#      31     def forward(self,x):
#      32         x=self.conv(x)
#      33         x=torch.flatten(x)
# ---> 34         x=self.fc(x)
#      35         return x
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x25600 and 400x120)
# ```

# %% [markdown]
# ## 修正：
# ### 由于卷积之后全连接过程中 torch.flatten(x)函数将x直接展开一维，忽略4dx的第一维度为batch_size不需要展开
# ```python
# torch.flatten(x,start_dim=1)  #放过第0个dim

# %% [markdown]
# # 报错3：存储权重时返回值错误

# %% [markdown]
# ```python
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 7
#       3
#       4
#       5 # 1. 加载模型
#       6 test_model = Lenet()
# ----> 7 test_model.load_state_dict(torch.load('lenet_mnist.params',weights_only=False))
#       8 test_model.to(device)  # 模型移到 GPU
#       9 test_model.eval()       # 切换到评估模式
#      10
#
# File C:\DL_code\.venv\Lib\site-packages\torch\nn\modules\module.py:2569, in Module.load_state_dict(self, state_dict, strict, assign)
#    2533 r"""Copy parameters and buffers from :attr:`state_dict` into this module and its descendants.
#    2534
#    2535 If :attr:`strict` is ``True``, then
#    (...)   2566     ``RuntimeError``.
#    2567 """
#    2568 if not isinstance(state_dict, Mapping):
# -> 2569     raise TypeError(
#    2570         f"Expected state_dict to be dict-like, got {type(state_dict)}."
#    2571     )
#    2573 missing_keys: list[str] = []
#    2574 unexpected_keys: list[str] = []
#
# TypeError: Expected state_dict to be dict-like, got <class 'method'>.
# ```

# %% [markdown]
# # 修正：出错返回的值类型为state_dict方法，错误在于存储/加载过程中state_dict()未加括号
